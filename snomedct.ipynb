# %%
#62479008

import pymedtermino
pymedtermino.LANGUAGE = "en"
pymedtermino.REMOVE_SUPPRESSED_CONCEPTS = True
from pymedtermino.all import *
from pymedtermino import *
from pymedtermino.snomedct import *

# %%
concept = SNOMEDCT[62479008]

# %%
concept.code
# Out:
# 62479008

# %%
concept.term
# Out:
# 'Acquired immune deficiency syndrome (disorder)'

# %%
concept.terms
# Out:
# ['AIDS',
#  'AIDS, NOS',
#  'Acquired immune deficiency syndrome, NOS',
#  'Acquired immunodeficiency syndrome, NOS',
#  'Acquired immune deficiency syndrome',
#  'Acquired immunodeficiency syndrome',
#  'Immunodeficiency due to human immunodeficiency virus infection',
#  'AIDS - Acquired immunodeficiency syndrome',
#  'AIDS (disorder)',
#  'Acquired immune deficiency syndrome (AIDS) (disorder)',
#  'Acquired immune deficiency syndrome (AIDS)',
#  'Acquired immune deficiency syndrome (disorder)']

# %%
concept1 = SNOMEDCT[165816005]

# %%
concept1.code
# Out:
# 165816005

# %%
concept1.term
# Out:
# 'Human immunodeficiency virus positive (finding)'

# %%
concept1.terms
# Out:
# ['HTLV-3 antibody positive',
#  'HIV positive',
#  'HIV positive (finding)',
#  'Human immunodeficiency virus (HIV) positive (finding)',
#  'Human immunodeficiency virus (HIV) positive',
#  'Human immunodeficiency virus positive (finding)',
#  'Human immunodeficiency virus positive']

# %%
y=SNOMEDCT.search("AIDS_DRUGS")

# %%
y
# Out:
# []

# %%
'SNOMEDCT[19030005]  # Human immunodeficiency virus (organism)' in y
# Out:
# False

# %%
len(y)
# Out:
# 139

# %%
y[0]
# Out:
# SNOMEDCT[19030005]  # Human immunodeficiency virus (organism)

# %%
string = ' '.join([str(elem) for elem in y])

# %%
string
# Out:
# "SNOMEDCT[19030005]  # Human immunodeficiency virus (organism)\n SNOMEDCT[48794007]  # Human immunodeficiency virus infection with infectious mononucleosis-like syndrome (disorder)\n SNOMEDCT[54893007]  # Feline immunodeficiency virus (organism)\n SNOMEDCT[62479008]  # Acquired immune deficiency syndrome (disorder)\n SNOMEDCT[79241002]  # Simian immunodeficiency virus (organism)\n SNOMEDCT[87117006]  # Human immunodeficiency virus infection with acute lymphadenitis (disorder)\n SNOMEDCT[102920009]  # Fear of contracting human immunodeficiency virus infection (finding)\n SNOMEDCT[103408004]  # Human immunodeficiency virus Centers for Disease Control and Prevention category A3 (acquired immunodeficiency syndrome) (finding)\n SNOMEDCT[103411003]  # Human immunodeficiency virus Centers for Disease Control and Prevention category B3 (acquired immunodeficiency syndrome) (finding)\n SNOMEDCT[103412005]  # Human immunodeficiency virus Centers for Disease Control and Prevention category C1 (acquired immunodeficiency syndrome) (finding)\n SNOMEDCT[103413000]  # Human immunodeficiency virus Centers for Disease Control and Prevention category C2 (acquired immunodeficiency syndrome) (finding)\n SNOMEDCT[103414006]  # Human immunodeficiency virus Centers for Disease Control and Prevention category C3 (acquired immunodeficiency syndrome) (finding)\n SNOMEDCT[103418009]  # Human immunodeficiency virus World Health Organization class IV (acquired immunodeficiency syndrome) (finding)\n SNOMEDCT[112379009]  # Bovine immunodeficiency virus (organism)\n SNOMEDCT[159103001]  # Audiovisual aids operator (occupation)\n SNOMEDCT[160680006]  # Fully mobile (finding)\n SNOMEDCT[165813002]  # Human immunodeficiency virus antibody test (procedure)\n SNOMEDCT[170530008]  # Notification of acquired immune deficiency syndrome (procedure)\n SNOMEDCT[171121004]  # Human immunodeficiency virus screening (procedure)\n SNOMEDCT[183135000]  # Mobility aid (physical object)\n SNOMEDCT[183364001]  # Use of aids for daily life (regime/therapy)\n SNOMEDCT[183365000]  # Use of kitchen aids (regime/therapy)\n SNOMEDCT[183366004]  # Use of bathroom aids (regime/therapy)\n SNOMEDCT[183367008]  # Use of work aids (regime/therapy)\n SNOMEDCT[183368003]  # Use of indoor mobility aids (regime/therapy)\n SNOMEDCT[224620002]  # Human aid to communication (occupation)\n SNOMEDCT[228616009]  # Provision of aids to daily living (procedure)\n SNOMEDCT[229026006]  # Sharing of sex aids (finding)\n SNOMEDCT[236406007]  # Acquired immune deficiency syndrome-related nephropathy (disorder)\n SNOMEDCT[266722002]  # Aids for severely handicapped (procedure)\n SNOMEDCT[266974005]  # Human immunodeficiency virus risk lifestyle (finding)\n SNOMEDCT[273263000]  # Acquired immunodeficiency syndrome risk behavior knowledge test (assessment scale)\n SNOMEDCT[273454004]  # Fear of acquired immunodeficiency syndrome scale (assessment scale)\n SNOMEDCT[273561002]  # Learning development aids - handwriting assessment (assessment scale)\n SNOMEDCT[276665006]  # Congenital acquired immune deficiency syndrome (disorder)\n SNOMEDCT[283993007]  # Use of memory retrieval aids (observable entity)\n SNOMEDCT[301569004]  # Ability to mobilize using mobility aids (observable entity)\n SNOMEDCT[301570003]  # Able to mobilize using mobility aids (finding)\n SNOMEDCT[301571004]  # Unable to mobilize using mobility aids (finding)\n SNOMEDCT[301572006]  # Does mobilize using aids (finding)\n SNOMEDCT[301573001]  # Does not mobilize using mobility aids (finding)\n SNOMEDCT[301574007]  # Difficulty mobilizing using mobility aids (finding)\n SNOMEDCT[309856005]  # Handicapped aids (procedure)\n SNOMEDCT[311884008]  # External memory aids training (regime/therapy)\n SNOMEDCT[360301002]  # Aids to daily living (physical object)\n SNOMEDCT[365111001]  # Finding related to ability to mobilize using mobility aids (finding)\n SNOMEDCT[365905000]  # Finding of use of memory retrieval aids (finding)\n SNOMEDCT[315019000]  #  ...

# %%
import re
t="mohith 0 9 0 "
result=re.findall(r"^ SNOMEDCT\[0-9]",string)
result
# Out:
# []

# %%
result
# Out:
# []

# %%
if re.search(r'^mohith',t):
    print("jirnfi")
# Out:
# jirnfi

# %%
t="mohith is good"
wiki
# Out:
# ['procedure',
#  'situation',
#  'acquired immunodeficiency syndrome',
#  'disorder',
#  'social concept',
#  'occupation',
#  'regime/therapy',
#  'physical object',
#  'finding',
#  'organism',
#  'assessment scale',
#  'observable entity']

# %%
result1
#type(result1)
result1 = re.split(r"#|\n",string)
#result1.group(0)
result1
result2=[]
for i in result1:
    res=re.findall(r"^ SNOMEDCT\[[0-9]+\]  |^SNOMEDCT\[[0-9]+\]  ",i)#mached snomedct word
    result2.append(res)
result2
result3=[ele for ele in result2 if ele!=[]]#remove empty list
result4=[]
for i in result3:
    for item in i:
        result4.append(item)#make ito a sinle list

result4
result5=[]
for j in result1:
    if j not in result4:
        result5.append(j.strip())
result5
#if 'AIDS' in result5:
#   print("mohith")
# Out:
# ['Human immunodeficiency virus (organism)',
#  'Human immunodeficiency virus infection with infectious mononucleosis-like syndrome (disorder)',
#  'Feline immunodeficiency virus (organism)',
#  'Acquired immune deficiency syndrome (disorder)',
#  'Simian immunodeficiency virus (organism)',
#  'Human immunodeficiency virus infection with acute lymphadenitis (disorder)',
#  'Fear of contracting human immunodeficiency virus infection (finding)',
#  'Human immunodeficiency virus Centers for Disease Control and Prevention category A3 (acquired immunodeficiency syndrome) (finding)',
#  'Human immunodeficiency virus Centers for Disease Control and Prevention category B3 (acquired immunodeficiency syndrome) (finding)',
#  'Human immunodeficiency virus Centers for Disease Control and Prevention category C1 (acquired immunodeficiency syndrome) (finding)',
#  'Human immunodeficiency virus Centers for Disease Control and Prevention category C2 (acquired immunodeficiency syndrome) (finding)',
#  'Human immunodeficiency virus Centers for Disease Control and Prevention category C3 (acquired immunodeficiency syndrome) (finding)',
#  'Human immunodeficiency virus World Health Organization class IV (acquired immunodeficiency syndrome) (finding)',
#  'Bovine immunodeficiency virus (organism)',
#  'Audiovisual aids operator (occupation)',
#  'Fully mobile (finding)',
#  'Human immunodeficiency virus antibody test (procedure)',
#  'Notification of acquired immune deficiency syndrome (procedure)',
#  'Human immunodeficiency virus screening (procedure)',
#  'Mobility aid (physical object)',
#  'Use of aids for daily life (regime/therapy)',
#  'Use of kitchen aids (regime/therapy)',
#  'Use of bathroom aids (regime/therapy)',
#  'Use of work aids (regime/therapy)',
#  'Use of indoor mobility aids (regime/therapy)',
#  'Human aid to communication (occupation)',
#  'Provision of aids to daily living (procedure)',
#  'Sharing of sex aids (finding)',
#  'Acquired immune deficiency syndrome-related nephropathy (disorder)',
#  'Aids for severely handicapped (procedure)',
#  'Human immunodeficiency virus risk lifestyle (finding)',
#  'Acquired immunodeficiency syndrome risk behavior knowledge test (assessment scale)',
#  'Fear of acquired immunodeficiency syndrome scale (assessment scale)',
#  'Learning development aids - handwriting assessment (assessment scale)',
#  'Congenital acquired immune deficiency syndrome (disorder)',
#  'Use of memory retrieval aids (observable entity)',
#  'Ability to mobilize using mobility aids (observable entity)',
#  'Able to mobilize using mobility aids (finding)',
#  'Unable to mobilize using mobility aids (finding)',
#  'Does mobilize using aids (finding)',
#  'Does not mobilize using mobility aids (finding)',
#  'Difficulty mobilizing using mobility aids (finding)',
#  'Handicapped aids (procedure)',
#  'External memory aids training (regime/therapy)',
#  'Aids to daily living (physical object)',
#  'Finding related to ability to mobilize using mobility aids (finding)',
#  'Finding of use of memory retrieval aids (finding)',
#  'Human immunodeficiency virus infection with aseptic meningitis (disorder)',
#  'Acquired Immunodeficiency Syndrome clinical trial group (social concept)',
#  'Pediatric Acquired Immunodeficiency Syndrome Clinical Trial Group (social concept)',
#  'Leukoplakia of tongue associated with human immunodeficiency virus disease (disorder)',
#  'Hairy leukoplakia of tongue associated with human immunodeficiency virus disease (disorder)',
#  'Neutropenia associated with acquired immunodeficiency syndrome (disorder)',
#  'Assistive device education (procedure)',
#  'Acquired immunodeficiency syndrome-associated disorder (disorder)',
#  'Abnormal weight loss associated with acquired immunodeficiency syndrome (finding)',
#  'Acute endocarditis associated with acquired immunodeficiency syndrome (disorder)',
#  'Myocarditis associated with acquired immunodeficiency syndrome (disorder)',
#  'Agranulocytosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Anemia associated with acquired immunodeficiency syndrome (disorder)',
#  'Acquired hemolytic anemia associated with acquired immunodeficiency syndrome (disorder)',
#  'Aplastic anemia associated with acquired immunodeficiency syndrome (disorder)',
#  'Retinopathy associated with acquired immunodeficiency syndrome (disorder)',
#  'Blindness associated with acquired immunodeficiency syndrome (disorder)',
#  'Cachexia associated with acquired immunodeficiency syndrome (finding)',
#  'Candidiasis of mouth associated with acquired immunodeficiency syndrome (disorder)',
#  'Central nervous disorder associated with acquired immunodeficiency syndrome (disorder)',
#  'Central nervous system demyelinating disease associated with acquired immunodeficiency syndrome (disorder)',
#  'Myelopathy associated with acquired immunodeficiency syndrome (disorder)',
#  'Coccidioidomycosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Cryptococcosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Disseminated candidiasis associated with acquired immunodeficiency syndrome (disorder)',
#  'Encephalopathy associated with acquired immunodeficiency syndrome (disorder)',
#  'Dementia associated with acquired immunodeficiency syndrome (disorder)',
#  'Encephalitis associated with acquired immunodeficiency syndrome (disorder)',
#  'Encephalomyelitis associated with acquired immunodeficiency syndrome (disorder)',
#  'Organic brain syndrome associated with acquired immunodeficiency syndrome (disorder)',
#  'Organic dementia associated with acquired immunodeficiency syndrome (disorder)',
#  'Presenile dementia associated with acquired immunodeficiency syndrome (disorder)',
#  'Primary lymphoma of brain associated with acquired immunodeficiency syndrome (disorder)',
#  'Progressive multifocal leukoencephalopathy associated with acquired immunodeficiency syndrome (disorder)',
#  'Subacute adenoviral encephalitis associated with acquired immunodeficiency syndrome (disorder)',
#  'Failure to thrive in infant associated with acquired immunodeficiency syndrome (disorder)',
#  'Fatigue associated with acquired immunodeficiency syndrome (disorder)',
#  'Hematopoietic system disease associated with acquired immunodeficiency syndrome (disorder)',
#  'Hepatomegaly associated with acquired immunodeficiency syndrome (disorder)',
#  'Herpes zoster associated with acquired immunodeficiency syndrome (disorder)',
#  'Histoplasmosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Ill-defined intestinal infection associated with acquired immunodeficiency syndrome (disorder)',
#  'Infectious gastroenteritis associated with acquired immunodeficiency syndrome (disorder)',
#  'Noninfectious gastroenteritis associated with acquired immunodeficiency syndrome (disorder)',
#  'Infective arthritis associated with acquired immunodeficiency syndrome (disorder)',
#  'Intestinal malabsorption associated with acquired immunodeficiency syndrome (disorder)',
#  'Low vision associated with acquired immunodeficiency syndrome (disorder)',
#  'Malaise associated with acquired immunodeficiency syndrome (disorder)',
#  'Malignant neoplasm associated with acquired immunodeficiency syndrome (disorder)',
#  "Kaposi's sarcoma associated with acquired immunodeficiency syndrome (disorder)",
#  'Reticulosarcoma associated with acquired immunodeficiency syndrome (disorder)',
#  'Microsporidiosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Mycobacteriosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Tuberculosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Myelitis associated with acquired immunodeficiency syndrome (disorder)',
#  'Neuralgia associated with acquired immunodeficiency syndrome (disorder)',
#  'Neuritis associated with acquired immunodeficiency syndrome (disorder)',
#  'Radiculitis associated with acquired immunodeficiency syndrome (disorder)',
#  'Nocardiosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Nutritional deficiency associated with acquired immunodeficiency syndrome (disorder)',
#  'Pneumocystosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Pneumonia associated with acquired immunodeficiency syndrome (disorder)',
#  'Bacterial pneumonia associated with acquired immunodeficiency syndrome (disorder)',
#  'Pneumococcal pneumonia associated with acquired immunodeficiency syndrome (disorder)',
#  'Candidiasis of lung associated with acquired immunodeficiency syndrome (disorder)',
#  'Viral pneumonia associated with acquired immunodeficiency syndrome (disorder)',
#  'Polyneuropathy associated with acquired immunodeficiency syndrome (disorder)',
#  'Respiratory disorder associated with acquired immunodeficiency syndrome (disorder)',
#  'Dyspnea associated with acquired immunodeficiency syndrome (disorder)',
#  'Retinal vascular changes associated with acquired immunodeficiency syndrome (disorder)',
#  'Salivary gland disease associated with acquired immunodeficiency syndrome (disorder)',
#  'Salmonella infection associated with acquired immunodeficiency syndrome (disorder)',
#  'Skin disorder associated with acquired immunodeficiency syndrome (disorder)',
#  'Dermatomycosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Hyperhidrosis associated with acquired immunodeficiency syndrome (disorder)',
#  'Skin rash associated with acquired immunodeficiency syndrome (disorder)',
#  'Strongyloidiasis associated with acquired immunodeficiency syndrome (disorder)',
#  'Subacute endocarditis associated with acquired immunodeficiency syndrome (disorder)',
#  'Subacute myocarditis associated with acquired immunodeficiency syndrome (disorder)',
#  'Thrombocytopenia associated with acquired immunodeficiency syndrome (disorder)',
#  'Family history of acquired immune deficiency syndrome (situation)',
#  'Cholangitis associated with acquired immunodeficiency syndrome (disorder)',
#  'Acquired immune deficiency syndrome complicating childbirth (disorder)',
#  'Kaposi sarcoma not associated with acquired immunodeficiency syndrome (disorder)',
#  'Assessment using Assessment of Intelligibility of Dysarthric Speech (procedure)',
#  'Assessment of Intelligibility of Dysarthric Speech (assessment scale)',
#  'Assessment of Intelligibility of Dysarthric Speech score (observable entity)',
#  'Infection caused by Coccidia co-occurrent with acquired immunodeficiency syndrome (disorder)',
#  'Infection caused by Toxoplasma gondii co-occurrent with acquired immunodeficiency syndrome (disorder)',
#  'Infection caused by Isospora co-occurrent with acquired immunodeficiency syndrome (disorder)',
#  'Assessment using Acquired Immunodeficiency Syndrome Risk Behavior Knowledge Test (procedure)',
#  'Acquired Immunodeficiency Syndrome Risk Behavior Knowledge Test total score (observable entity)',
#  '']

# %%
for i in result3:
    print(i)
# Out:
# ['SNOMEDCT[19030005]  ']
# [' SNOMEDCT[48794007]  ']
# [' SNOMEDCT[54893007]  ']
# [' SNOMEDCT[62479008]  ']
# [' SNOMEDCT[79241002]  ']
# [' SNOMEDCT[87117006]  ']
# [' SNOMEDCT[102920009]  ']
# [' SNOMEDCT[103408004]  ']
# [' SNOMEDCT[103411003]  ']
# [' SNOMEDCT[103412005]  ']
# [' SNOMEDCT[103413000]  ']
# [' SNOMEDCT[103414006]  ']
# [' SNOMEDCT[103418009]  ']
# [' SNOMEDCT[112379009]  ']
# [' SNOMEDCT[159103001]  ']
# [' SNOMEDCT[160680006]  ']
# [' SNOMEDCT[165813002]  ']
# [' SNOMEDCT[170530008]  ']
# [' SNOMEDCT[171121004]  ']
# [' SNOMEDCT[183135000]  ']
# [' SNOMEDCT[183364001]  ']
# [' SNOMEDCT[183365000]  ']
# [' SNOMEDCT[183366004]  ']
# [' SNOMEDCT[183367008]  ']
# [' SNOMEDCT[183368003]  ']
# [' SNOMEDCT[224620002]  ']
# [' SNOMEDCT[228616009]  ']
# [' SNOMEDCT[229026006]  ']
# [' SNOMEDCT[236406007]  ']
# [' SNOMEDCT[266722002]  ']
# [' SNOMEDCT[266974005]  ']
# [' SNOMEDCT[273263000]  ']
# [' SNOMEDCT[273454004]  ']
# [' SNOMEDCT[273561002]  ']
# [' SNOMEDCT[276665006]  ']
# [' SNOMEDCT[283993007]  ']
# [' SNOMEDCT[301569004]  ']
# [' SNOMEDCT[301570003]  ']
# [' SNOMEDCT[301571004]  ']
# [' SNOMEDCT[301572006]  ']
# [' SNOMEDCT[301573001]  ']
# [' SNOMEDCT[301574007]  ']
# [' SNOMEDCT[309856005]  ']
# [' SNOMEDCT[311884008]  ']
# [' SNOMEDCT[360301002]  ']
# [' SNOMEDCT[365111001]  ']
# [' SNOMEDCT[365905000]  ']
# [' SNOMEDCT[315019000]  ']
# [' SNOMEDCT[406528008]  ']
# [' SNOMEDCT[409113002]  ']
# [' SNOMEDCT[414604009]  ']
# [' SNOMEDCT[414376003]  ']
# [' SNOMEDCT[416729007]  ']
# [' SNOMEDCT[370875004]  ']
# [' SNOMEDCT[420721002]  ']
# [' SNOMEDCT[421695000]  ']
# [' SNOMEDCT[420395004]  ']
# [' SNOMEDCT[421929001]  ']
# [' SNOMEDCT[421312009]  ']
# [' SNOMEDCT[420543008]  ']
# [' SNOMEDCT[421851008]  ']
# [' SNOMEDCT[421102007]  ']
# [' SNOMEDCT[421460008]  ']
# [' SNOMEDCT[421706001]  ']
# [' SNOMEDCT[422003001]  ']
# [' SNOMEDCT[421710003]  ']
# [' SNOMEDCT[421998001]  ']
# [' SNOMEDCT[420718004]  ']
# [' SNOMEDCT[420452002]  ']
# [' SNOMEDCT[422337001]  ']
# [' SNOMEDCT[421403008]  ']
# [' SNOMEDCT[421077004]  ']
# [' SNOMEDCT[421827003]  ']
# [' SNOMEDCT[421529006]  ']
# [' SNOMEDCT[420244003]  ']
# [' SNOMEDCT[422089004]  ']
# [' SNOMEDCT[420774007]  ']
# [' SNOMEDCT[420614009]  ']
# [' SNOMEDCT[421023003]  ']
# [' SNOMEDCT[421283008]  ']
# [' SNOMEDCT[420554003]  ']
# [' SNOMEDCT[421415007]  ']
# [' SNOMEDCT[421660003]  ']
# [' SNOMEDCT[420900006]  ']
# [' SNOMEDCT[420384005]  ']
# [' SNOMEDCT[421230000]  ']
# [' SNOMEDCT[422127002]  ']
# [' SNOMEDCT[420945005]  ']
# [' SNOMEDCT[420687005]  ']
# [' SNOMEDCT[421454008]  ']
# [' SNOMEDCT[421983003]  ']
# [' SNOMEDCT[421708000]  ']
# [' SNOMEDCT[420321004]  ']
# [' SNOMEDCT[422189002]  ']
# [' SNOMEDCT[420801006]  ']
# [' SNOMEDCT[422282000]  ']
# [' SNOMEDCT[420524008]  ']
# [' SNOMEDCT[420302007]  ']
# [' SNOMEDCT[421020000]  ']
# [' SNOMEDCT[420818005]  ']
# [' SNOMEDCT[421571007]  ']
# [' SNOMEDCT[421315006]  ']
# [' SNOMEDCT[422136003]  ']
# [' SNOMEDCT[422012004]  ']
# [' SNOMEDCT[420658009]  ']
# [' SNOMEDCT[421431004]  ']
# [' SNOMEDCT[420691000]  ']
# [' SNOMEDCT[420403001]  ']
# [' SNOMEDCT[421671002]  ']
# [' SNOMEDCT[420544002]  ']
# [' SNOMEDCT[420787001]  ']
# [' SNOMEDCT[421047005]  ']
# [' SNOMEDCT[421508002]  ']
# [' SNOMEDCT[421597001]  ']
# [' SNOMEDCT[421874007]  ']
# [' SNOMEDCT[422177004]  ']
# [' SNOMEDCT[420308006]  ']
# [' SNOMEDCT[420549007]  ']
# [' SNOMEDCT[420764009]  ']
# [' SNOMEDCT[421394009]  ']
# [' SNOMEDCT[420877009]  ']
# [' SNOMEDCT[422194002]  ']
# [' SNOMEDCT[420281004]  ']
# [' SNOMEDCT[421883002]  ']
# [' SNOMEDCT[420938005]  ']
# [' SNOMEDCT[421272004]  ']
# [' SNOMEDCT[421766003]  ']
# [' SNOMEDCT[441120009]  ']
# [' SNOMEDCT[697965002]  ']
# [' SNOMEDCT[10746341000119109]  ']
# [' SNOMEDCT[703625002]  ']
# [' SNOMEDCT[716776005]  ']
# [' SNOMEDCT[716873009]  ']
# [' SNOMEDCT[716874003]  ']
# [' SNOMEDCT[771119002]  ']
# [' SNOMEDCT[771126002]  ']
# [' SNOMEDCT[771127006]  ']
# [' SNOMEDCT[781146004]  ']
# [' SNOMEDCT[781147008]  ']

# %%
concept.parents
#result2
# Out:
# [SNOMEDCT[86406008]  # Human immunodeficiency virus infection (disorder),
#  SNOMEDCT[33286000]  # Secondary immune deficiency disorder (disorder),
#  SNOMEDCT[312130009]  # Viral infection by site (disorder),
#  SNOMEDCT[363161007]  # Infectious disorder of immune system (disorder),
#  SNOMEDCT[81000119104]  # Symptomatic human immunodeficiency virus infection (disorder)]

# %%
concept1.children
# Out:
# [SNOMEDCT[713742005]  # Human immunodeficiency virus antibody positive (finding),
#  SNOMEDCT[719789000]  # Human immunodeficiency virus 2 antibody positive and Human immunodeficiency virus 1 antibody cross-reactivity (finding)]

# %%
#for ancestor in concept.ancestors(): 
 #   print(ancestor)

# %%
concept.ancestors()

# %%
list(concept.ancestors())

# %%
#list(concept.descendants())

# %%
concept.is_a(SNOMEDCT[86406008])

# %%
concept.is_a(SNOMEDCT[272625005])

# %%
concept1.part_of

# %%
concept.INVERSE_part_of

# %%
list(concept.ancestor_parts())

# %%
list(concept.descendant_parts())

# %%
concept.is_part_of(SNOMEDCT[86406008])

# %%
concept = SNOMEDCT[3424008]

# %%
concept

# %%
concept.relations

# %%
#concept.finding_site
#concept.INVERSE_associated_finding
concept.has_interpretation

# %%
concept.interprets

# %%
#concept.INVERSE_has_definitional_manifestation

# %%
concept.INVERSE_associated_with

# %%
SNOMEDCT[186675001]

# %%
#SNOMEDCT[186675001].groups

# %%
#SNOMEDCT[186675001].groups[0].finding_site

# %%
SNOMEDCT.first_levels()

# %%
'''for concept in SNOMEDCT.all_concepts():
    print(concept)'''

# %%
#SNOMEDCT[80891009].associated_clinical_findings()

# %%
from pymedtermino import *
from pymedtermino.icd10 import *

# %%
ICD10["F02.4"]

# %%
ICD10["F02.4"].parents

# %%
list(ICD10["F02.4"].ancestors())

# %%
print(ICD10["F02.4"].get_translation("fr"))

# %%
print(ICD10["F02.4"].get_translation("en"))

# %%
pymedtermino.icd10.ATIH_EXTENSION = True

# %%
ICD10["E10"].relations

# %%
ICD10["E10"].exclusion

# %%
from pymedtermino import *

# %%
from pymedtermino.umls import *

# %%
import MySQLdb
connect_to_umls_db('localhost', 'root','mohithamma03', "snomedct",  "latin1")

# %%
import MySQLdb
#for concept in SNOMEDCT.all_concepts():
 #   print(concept)
for core_concept in SNOMEDCT.CORE_problem_list():
    print(core_concept)
concept.is_in_core

# %%
 #UMLS_AUI[u"A0930328"]

# %%
from pymedtermino import *
from pymedtermino.vcm import *

# %%
icon = VCM["en_cours--patho--coeur"]
icon = VCM["current--patho--heart"]
icon = VCM["en_cours--patho-vaisseau--coeur--traitement--medicament--rien--rien"]

# %%
icon.central_color
# Out:
# VCM_LEXICON[496]  # Red_color

# %%
icon.central_pictogram
# Out:
# VCM_LEXICON[549]  # Pictogramme_heart

# %%
icon.central_pictogram.text_code
# Out:
# 'heart'

# %%
icon.top_right_color
# Out:
# VCM_LEXICON[690]  # Green_color

# %%
icon.top_right_pictogram
# Out:
# VCM_LEXICON[697]  # Drug_top_right_pictogram

# %%
icon.second_top_right_pictogram
# Out:
# VCM_LEXICON[718]  # No_second_top_right_pictogram

# %%
icon.shadow
# Out:
# VCM_LEXICON[722]  # No_shadow

# %%
icon.lexs
# Out:
# Concepts([
#   VCM_LEXICON[690]  # Green_color
# , VCM_LEXICON[718]  # No_second_top_right_pictogram
# , VCM_LEXICON[496]  # Red_color
# , VCM_LEXICON[549]  # Pictogramme_heart
# , VCM_LEXICON[722]  # No_shadow
# , VCM_LEXICON[697]  # Drug_top_right_pictogram
# , VCM_LEXICON[504]  # Modifier_patho
# , VCM_LEXICON[536]  # Modifier_vessel
# ])

# %%
icon.physio
icon.patho
icon.etiology
icon.quantitative
icon.process
icon.transverse
# Out:
# VCM_LEXICON[536]  # Modifier_vessel

# %%
icon.consistent
# Out:
# True

# %%
icon.process

# %%
heart = VCM_LEXICON[659]
heart
# Out:
# VCM_LEXICON[659]  # Abdomen_pictogram

# %%
heart.text_code
# Out:
# 'abdomen'

# %%
heart.category
# Out:
# 2

# %%
VCM_LEXICON[2, "heart"]
# Out:
# VCM_LEXICON[549]  # Pictogramme_heart

# %%
heart_rhythm = VCM_LEXICON[2, "heart_rhythm"]

# %%
heart_rhythm.graphical_is_a
# Out:
# [VCM_LEXICON[549]  # Pictogramme_heart]

# %%
Concepts([VCM_LEXICON[549], VCM_LEXICON[496], VCM_LEXICON[504]]) >> VCM
# Out:
# Concepts([
#   VCM[u"current--patho--heart"]  # disorder of heart or pericardia
# ])

# %%
 heart = VCM_CONCEPT[266]

# %%
heart
# Out:
# VCM_CONCEPT[266]  # Cardiac_structure

# %%
#concept("aids") >> DESTINATION_TERMINOLOGY

# %%
UMLS_CUI[u"C0085580"] >> UMLS_AUI

# %%
from pymedtermino.snomedct_2_vcm import *
SNOMEDCT[3424008]
SNOMEDCT[3424008]  # Tachycardia (finding)
SNOMEDCT[3424008] >> VCM

# %%
VCM_CONCEPT[266] >> VCM_LEXICON

# %%
Concepts([VCM_LEXICON[549], VCM_LEXICON[496], VCM_LEXICON[504]]) >> VCM

# %%
VCM_CONCEPT[266] >> VCM_LEXICON

# %%
VCM_LEXICON[549] >> VCM_CONCEPT

# %%
SNOMEDCT[302509004]

# %%
SNOMEDCT[302509004] >> VCM_CONCEPT

# %%
 y=SNOMEDCT.search("cancer")

# %%
y

# %%
string = ' '.join([str(elem) for elem in y])
#type(result1)
result1 = re.split(r"#|\n",string)
#result1.group(0)
result1
result2=[]
for i in result1:
    res=re.findall(r"^ SNOMEDCT\[[0-9]+\]  |^SNOMEDCT\[[0-9]+\]  ",i)#mached snomedct word
    result2.append(res)
result2
result3=[ele for ele in result2 if ele!=[]]#remove empty list
result4=[]
for i in result3:
    for item in i:
        result4.append(item)#make ito a sinle list

result4
result5=[]
for j in result1:
    if j not in result4:
        result5.append(j.strip())
result5

result1 = re.findall(r"(?i)(.* cancer .*)",string)

# %%
result1

# %%
from nlpre import titlecaps, dedash, identify_parenthetical_phrases
from nlpre import replace_acronyms, replace_from_dictionary

f=open('106886.txt')
text = (f.read())

ABBR = identify_parenthetical_phrases()(text)
parsers = [dedash(), titlecaps(), replace_acronyms(ABBR),
           replace_from_dictionary(prefix="Medcicalterm_")]

for f in parsers:
    text = f(text)

#print(text)
import re
text1=re.findall(r"Medcicalterm_.*[\S]",text)
text1
#len(text1)
# Out:
# ['Medcicalterm_Coronary_Artery_Disease | Signed |',
#  'Medcicalterm_Thoracic_Surgery Service .',
#  'Medcicalterm_Coronary_Artery_Disease .',
#  'Medcicalterm_Inferior_Wall_Myocardial_Infarction in 1995 , which was treated with angioplasty at that time .',
#  'Medcicalterm_Chest_Pain with exertion .',
#  'Medcicalterm_Exercise_Test , which was found to be abnormal , and was referred for Medcicalterm_Cardiac_Catheterization .',
#  'Medcicalterm_Cardiac_Catheterization was performed on 10/3/06 at Au Hospital .',
#  'Medcicalterm_Coronary_Vessels , a 90 % mid segment stenosis of his first diagonal Medcicalterm_Coronary_Vessels , a 50 % mid segment stenosis of his circumflex Medcicalterm_Coronary_Vessels , a 90 % ostial stenosis of his first obtuse marginal , a 100 % proximal stenosis of his right Medcicalterm_Coronary_Vessels as well as a 30 % ostial stenosis of the left main Medcicalterm_Coronary_Vessels .',
#  'Medcicalterm_Coronary_Vessels .',
#  'Medcicalterm_Cardiac_Catheterization , he was referred for elective revascularization .',
#  'Medcicalterm_Low_Back_Pain , nephrolithiasis as well as a 3.4 cm infrarenal Medcicalterm_Aortic_Aneurysm_Abdominal at the bifurcation of the aorta .',
#  'Medcicalterm_Coronary_Artery_Disease .',
#  'Medcicalterm_Coronary_Artery_Bypass in the past and his mother , father and brother all have suffered Medcicalterm_Myocardial_Infarction .',
#  'Medcicalterm_Smoking history as well as a history of social alcohol use , approximately five to six beers on the weekend .',
#  'Medcicalterm_Drug_Hypersensitivity , however tetanus immunization in the past has led to arm swelling .',
#  'Medcicalterm_Low_Back_Pain as well as vitamins C , D , A , and E.',
#  'Medcicalterm_Physical_Examination .',
#  'Medcicalterm_Physical_Examination',
#  'Medcicalterm_Physical_Examination at that time revealed the patient to be afebrile with resting Medcicalterm_Heart_Rate of 52 beats per minute and regular .',
#  'Medcicalterm_Blood_Pressure of 142/76 in the right arm and 148/76 in the left arm .',
#  'Medcicalterm_Carotid_Arteries .',
#  'Medcicalterm_Systolic_Murmurs heard best at the right upper sternal border .',
#  'Medcicalterm_Leukocyte_Count of 10.9 , hematocrit 49.2 , and Medcicalterm_Platelet_Count of 386 , 000 .',
#  'Medcicalterm_Cardiac_Catheterization data from 10/3/06 are as stated above in the history of present illness .',
#  'Medcicalterm_Mitral_Valve_Insufficiency and no noted regional wall motion abnormalities .',
#  'Medcicalterm_X-Rays performed on 1/25/2006 was without evidence of active cardiopulmonary disease .',
#  'Medcicalterm_Operating_Rooms where he underwent Medcicalterm_Coronary_Artery_Bypass x4 including the left Medcicalterm_Mammary_Arteries to left anterior descending Medcicalterm_Coronary_Vessels , Medcicalterm_Saphenous_Vein graft to the ramus and second obtuse marginal Medcicalterm_Coronary_Vessels and the left Medcicalterm_Radial_Artery to the right Medcicalterm_Coronary_Vessels .',
#  'Medcicalterm_Cardiopulmonary_Bypass time of 173 minutes with an aortic cross-clamp time of 156 minutes .',
#  'Medcicalterm_Postoperative_Period was uncomplicated .',
#  'Medcicalterm_Intensive_Care_Units to the Step-Down Unit on postoperative day # 1 .',
#  'Medcicalterm_Leukocyte_Count of approximately 17 in the immediate Medcicalterm_Perioperative_Period , however the Medcicalterm_Leukocyte_Count had improved markedly to 11.9 by postoperative day',
#  'Medcicalterm_X-Rays on postoperative day # 3 , which revealed satisfactory postoperative appearance of the chest .',
#  'Medcicalterm_Nurses_Community_Health services on 7/4/06 , postoperative day # 4 .',
#  'Medcicalterm_Hemoglobin_A A1c of 7.2 prior to admission .',
#  'Medcicalterm_Physicians_Primary_Care in 1-2 weeks for follow-up check of his Medcicalterm_Blood_Glucose and any necessary adjustment in his diabetic medications .',
#  'Medcicalterm_Physicians_Primary_Care , Dr. Parmalee one to two weeks following discharge from the hospital .']

# %%
text1

# %%
text1=re.findall(r"MeSH_.*[\S]",text)

# %%
text1
# Out:
# ['MeSH_Coronary_Artery_Disease | Signed |',
#  'MeSH_Thoracic_Surgery Service .',
#  'MeSH_Coronary_Artery_Disease .',
#  'MeSH_Inferior_Wall_Myocardial_Infarction in 1995 , which was treated with angioplasty at that time .',
#  'MeSH_Chest_Pain with exertion .',
#  'MeSH_Exercise_Test , which was found to be abnormal , and was referred for MeSH_Cardiac_Catheterization .',
#  'MeSH_Cardiac_Catheterization was performed on 10/3/06 at Au Hospital .',
#  'MeSH_Coronary_Vessels , a 90 % mid segment stenosis of his first diagonal MeSH_Coronary_Vessels , a 50 % mid segment stenosis of his circumflex MeSH_Coronary_Vessels , a 90 % ostial stenosis of his first obtuse marginal , a 100 % proximal stenosis of his right MeSH_Coronary_Vessels as well as a 30 % ostial stenosis of the left main MeSH_Coronary_Vessels .',
#  'MeSH_Coronary_Vessels .',
#  'MeSH_Cardiac_Catheterization , he was referred for elective revascularization .',
#  'MeSH_Low_Back_Pain , nephrolithiasis as well as a 3.4 cm infrarenal MeSH_Aortic_Aneurysm_Abdominal at the bifurcation of the aorta .',
#  'MeSH_Coronary_Artery_Disease .',
#  'MeSH_Coronary_Artery_Bypass in the past and his mother , father and brother all have suffered MeSH_Myocardial_Infarction .',
#  'MeSH_Smoking history as well as a history of social alcohol use , approximately five to six beers on the weekend .',
#  'MeSH_Drug_Hypersensitivity , however tetanus immunization in the past has led to arm swelling .',
#  'MeSH_Low_Back_Pain as well as vitamins C , D , A , and E.',
#  'MeSH_Physical_Examination .',
#  'MeSH_Physical_Examination',
#  'MeSH_Physical_Examination at that time revealed the patient to be afebrile with resting MeSH_Heart_Rate of 52 beats per minute and regular .',
#  'MeSH_Blood_Pressure of 142/76 in the right arm and 148/76 in the left arm .',
#  'MeSH_Carotid_Arteries .',
#  'MeSH_Systolic_Murmurs heard best at the right upper sternal border .',
#  'MeSH_Leukocyte_Count of 10.9 , hematocrit 49.2 , and MeSH_Platelet_Count of 386 , 000 .',
#  'MeSH_Cardiac_Catheterization data from 10/3/06 are as stated above in the history of present illness .',
#  'MeSH_Mitral_Valve_Insufficiency and no noted regional wall motion abnormalities .',
#  'MeSH_X-Rays performed on 1/25/2006 was without evidence of active cardiopulmonary disease .',
#  'MeSH_Operating_Rooms where he underwent MeSH_Coronary_Artery_Bypass x4 including the left MeSH_Mammary_Arteries to left anterior descending MeSH_Coronary_Vessels , MeSH_Saphenous_Vein graft to the ramus and second obtuse marginal MeSH_Coronary_Vessels and the left MeSH_Radial_Artery to the right MeSH_Coronary_Vessels .',
#  'MeSH_Cardiopulmonary_Bypass time of 173 minutes with an aortic cross-clamp time of 156 minutes .',
#  'MeSH_Postoperative_Period was uncomplicated .',
#  'MeSH_Intensive_Care_Units to the Step-Down Unit on postoperative day # 1 .',
#  'MeSH_Leukocyte_Count of approximately 17 in the immediate MeSH_Perioperative_Period , however the MeSH_Leukocyte_Count had improved markedly to 11.9 by postoperative day',
#  'MeSH_X-Rays on postoperative day # 3 , which revealed satisfactory postoperative appearance of the chest .',
#  'MeSH_Nurses_Community_Health services on 7/4/06 , postoperative day # 4 .',
#  'MeSH_Hemoglobin_A A1c of 7.2 prior to admission .',
#  'MeSH_Physicians_Primary_Care in 1-2 weeks for follow-up check of his MeSH_Blood_Glucose and any necessary adjustment in his diabetic medications .',
#  'MeSH_Physicians_Primary_Care , Dr. Parmalee one to two weeks following discharge from the hospital .']

# %%
import re
import string
from nltk.corpus import stopwords
def clean_text_round1(text):
    #Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    stop_words=stopwords.words('english')
    text1=[]
    for i in text:
        if i not in stop_words:
            text1.append(i)
    text=text1
    return text
file1 = open("14806output.txt","r+")
with open( "Downloads/14806.txt", "r+") as file:
    res=file.read()
    res1= clean_text_round1(''.join(map(str,res)))
    #print(res1)
    #file1.write(''.join(map(str,res)))
y=file1.read()
y
import spacy

from scispacy.abbreviation import AbbreviationDetector

nlp = spacy.load("en_core_sci_sm")

# Add the abbreviation pipe to the spacy pipeline.
abbreviation_pipe = AbbreviationDetector(nlp)
nlp.add_pipe(abbreviation_pipe)

doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor (AIDS) disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

print("Abbreviation", "\t", "Definition")
for abrv in doc._.abbreviations:
    print(f"{abrv} \t ({abrv.start}, {abrv.end}) {abrv._.long_form}")
# Out:
# Abbreviation 	 Definition
# SBMA 	 (35, 36) Spinal and bulbar muscular atrophy
# SBMA 	 (6, 7) Spinal and bulbar muscular atrophy
# AR 	 (31, 32) androgen receptor

# %%
file2= open("14806output.txt","r")
text = file2.read()
doc = nlp(text)

print(list(doc.sents))
# Out:
# [﻿RECORD #14806 421857826 | BHO | 95616398 | | 9654751 | 8/0/2006 12:00:00 AM | HAND CELLULITIS | Signed | DIS | Admission Date: 7/22/2006 Report Status: Signed Discharge Date: 5/24/2006
# ATTENDING: DEMONT , CRAIG JEWELL MD
# PRINCIPAL DIAGNOSIS: Cellulitis.
# , LIST OF PROBLEMS/DIAGNOSES:
# 1., Inflammatory breast cancer.
# , 2., Type II diabetes.
# , 3., Hypertension.
# , 4., Hypercholesterolemia.
# , 5., CHF with preserved systolic function.
# , 6., Obstructive sleep apnea.
# , 7., Asthma.
# , 8., Spinal stenosis with herniated discs.
# , BRIEF HISTORY OF PRESENT ILLNESS:, Ms. Schwarzer is a 72-year-old female with newly diagnosed ductal carcinoma and inflammatory breast cancer of the left breast with a mass in the lung that is suggestive of likely stage IV disease who has also multiple other medical problem including diabetes , who presents with a two-day history of right and left finger warmth , tenderness and swelling., The patient is undergoing chemotherapy with Adriamycin and cytoxan and is status post cycle 2 on 10/28/06 and began to feel like she was recovering from her chemotherapy approximately three days prior to admission., A spinal MRI obtained on Tuesday to evaluate her spinal stenosis was uneventful but later on that day the patient developed redness on the dorsum of her right hand in the area in which her IV was placed per the MRI., The following morning the patient had a pustular lesion on the fourth digit of her right hand distal to the dorsal redness and went to EH Urgent Care where she received one dose of ceftriaxone and was given a p.o., script for Augmentin., She was sent home but at home she developed expulsive diarrhea and vomiting on that evening , was not able to tolerate her oral antibiotics., The next day she noticed a similar lesion on the fourth digit of her left hand looking much like that on the right hand., She returned to the TMHMC urgent care for one more dose of ceftriaxone and was then admitted to the hospital for IV antibiotics., The patient denies any cat bites , travel , soil or water contract., She has no bruises , scrapes or previous lesions.
# , PAST MEDICAL HISTORY: As detailed above.
# , MEDICINES:
# 1., Lantus 40 units nightly.
# , 2., Aspirin 81 mg daily.
# , 3., Lipitor 40 mg daily.
# , 4., Zestril 2.5 mg daily.
# , 5., Cardizem ER 240 mg daily.
# , 6., Lasix 20 mg daily.
# , 7., Procrit 40000 units weekly.
# , 8., Pamidronate.
# , 9., Dexamethasone with chemotherapy.
# , 10., AC chemo.
# , 11., Neulasta.
# , 12., Ativan p.r.n.
# , 13., Multivitamin.
# , 14., Iron sulfate.
# , 15., Isosorbide dinitrate 10 mg t.i.d.
# , 11., Allegra 60 , 000 mg b.i.d.
# , ALLERGIES:
# 1., Percodan.
# , 2., Halothane causing fevers.
# , 3., Atenolol causing sweating.
# , 4., Sulfa causes a rash.
# , SOCIAL HISTORY: The patient lives alone in Te, She has a very sad social history in which her husband is a TX war veteran and came back to the Ra and was service connected with the pofield medical center of psychiatric disturbances following his tour of duty., She has had three sons , two twins who died earlier in life of some unspecified heart illness and a third son who died at the age of 21 after a long hospital stay with clear cell sarcoma of bone., She lives alone
# in a second floor walkup in Du near, Inslareca Cou Pla She
# has a distant history of tobacco 50 years ago., She rarely drinks
# alcohol., Her friend and healthcare proxy is Ezekiel Stoviak , and
# the phone # 286-432-6775.
# , FAMILY HISTORY, : There is no history of breast cancer., Mother
# had colon cancer., Three aunts and maternal grandmother also had
# colon cancer., Her son had a clear cell sarcoma of bone.
# , REVIEW OF SYSTEMS: Positive for nausea , vomiting , diarrhea ,
# lightheadedness and dizziness associated with her chemo but she
# denies fevers , chills , sweats in the past 72 to 96 hours prior to
# admission., She did have chest pain on 1/22/06 two days after
# her chemo but none since and in the time leading up to her
# hospitalization.
# , ADMISISON PHYSICAL EXAM, : Temperature was 98.9 , pulse 98 , blood
# pressure 132/55 , respiratory rate 16 , 95% on room air., The
# patient's physical exam was significant for alopecia and obesity.
# , She was in no acute distress , alert and oriented., Her pupils
# were equal , round and reactive., Conjunctivae were pink., She was
# anicteric and her oropharynx was clear., JVP was hard to assess
# due to neck fullness and she wears hearing aids., The lungs were
# clear to auscultation except for decreased breath sounds with
# crackles at the left base., Cardiovascular exam was regular rate
# and rhythm with a normal S1 , S2 and no murmur , rubs or gallops.
# , Abdomen was soft and benign., Extremities had trace to 1+ edema.
# , The patient had an approximately 4 x 2 cm area of redness but no
# swelling , positive warmth and positive tenderness on the dorsal
# surface of her right hand., She had a pustular lesion on her left
# fourth digit and right third digit that had been I&amp;D in AH
# Urgent Care.
# , LABORATORY DATA: Labs are significant for creatinine of 1 , white
# blood cell count of 4.33 , hematocrit of 25.5 and platelets of
# 108., EKG showed a normal sinus rhythm with a leftward axis and
# first degree AV block., Chest x-ray was unremarkable.
# , HOSPITAL COURSE BY PROBLEM, : This is a 72-year-old woman with
init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ﻿RECORD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  #14806 421857826 |
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BHO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  | 95616398 | | 9654751 | 8/0/2006 12:00:00 AM |
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HAND
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  CELLULITIS | Signed | DIS | Admission Date: 7/22/2006
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Report Status
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Signed Discharge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  Date: 5/24/2006</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ATTENDING
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DEMONT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CRAIG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  JEWELL
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PRINCIPAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DIAGNOSIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cellulitis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  OF
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROBLEMS/DIAGNOSES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :</br>1.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Inflammatory breast cancer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>2.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Type II diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>3.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>4.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hypercholesterolemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>5.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  with preserved
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     systolic function
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>6.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obstructive sleep apnea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>7.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asthma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .</br>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...

# %%
import wikipedia

# %%
print(wikipedia.summary("Wikipedia"))
# Out:
# The English Wikipedia is the English-language edition of the free online encyclopedia Wikipedia. Founded on 15 January 2001, it is the first edition of Wikipedia and, as of April 2019, has the most articles of any edition. As of September 2020, 11% of articles in all Wikipedias belong to the English-language edition. This share has gradually declined from more than 50 percent in 2003, due to the growth of Wikipedias in other languages. As of 21 September 2020, there are 6,161,563 articles on the site, having surpassed the 6 million mark on 23 January 2020. In August 2019, the total volume of the compressed texts of the English Wikipedia's articles amounted to 16.1 gigabytes.The Simple English Wikipedia (simplewiki) is a variation in which most articles use only basic English vocabulary. There is also the Old English (Ænglisc/Anglo-Saxon) Wikipedia (angwiki). Community-produced news publications include The Signpost.

# %%
wikipedia.search("bipolar")

# %%
ny = wikipedia.page("New York")
# Out:
# /home/mohith/anaconda3/lib/python3.7/site-packages/wikipedia/wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /home/mohith/anaconda3/lib/python3.7/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# ---------------------------------------------------------------------------
# DisambiguationError                       Traceback (most recent call last)
# <ipython-input-14-8755bb978ba9> in <module>
# ----> 1 ny = wikipedia.page("New York")
#       2 from tranformers import pipeline
#
# ~/anaconda3/lib/python3.7/site-packages/wikipedia/wikipedia.py in page(title, pageid, auto_suggest, redirect, preload)
#     274         # if there is no suggestion or search results, the page doesn't exist
#     275         raise PageError(title)
# --> 276     return WikipediaPage(title, redirect=redirect, preload=preload)
#     277   elif pageid is not None:
#     278     return WikipediaPage(pageid=pageid, preload=preload)
#
# ~/anaconda3/lib/python3.7/site-packages/wikipedia/wikipedia.py in __init__(self, title, pageid, redirect, preload, original_title)
#     297       raise ValueError("Either a title or a pageid must be specified")
#     298
# --> 299     self.__load(redirect=redirect, preload=preload)
#     300
#     301     if preload:
#
# ~/anaconda3/lib/python3.7/site-packages/wikipedia/wikipedia.py in __load(self, redirect, preload)
#     391       may_refer_to = [li.a.get_text() for li in filtered_lis if li.a]
#     392
# --> 393       raise DisambiguationError(getattr(self, 'title', page['title']), may_refer_to)
#     394
#     395     else:
#
# DisambiguationError: "New York" may refer to:
# New York City
# New York (state)
# New York (1916 film)
# New York (1927 film)
# New York (2009 film)
# New York: A Documentary Film
# "New York" (Glee)
# New York (Anthony Burgess book)
# New York (Morand book)
# New York (novel)
# New York (magazine)
# New York EP
# "New York" (Angel Haze song)
# New York (album)
# "New York" (Eskimo Joe song)
# "New York" (Ja Rule song)
# "New York" (Paloma Faith song)
# "New York" (St. Vincent song)
# "New York" (Snow Patrol song)
# "New York" (U2 song)
# Antti Tuisku
# Never Mind the Bollocks, Here's the Sex Pistols
# New York, Lincolnshire
# New York, North Yorkshire
# New York, Tyne and Wear
# New York metropolitan area
# New York County
# U.S. Postal Service address designating Manhattan
# Province of New York
# New York, Florida
# New York, Iowa
# New York, Kentucky
# New York, Missouri
# New York, Texas
# New York Mountain
# List of ships named New York
# List of ships named City of New York
# List of ships named New York City
# New York Giants
# New York Jets
# New York (World Series of Football)
# New York Mets
# New York Yankees
# New York Islanders
# New York Rangers
# New York City FC
# New York Red Bulls
# New York Stadium
# New York GAA
# New York Knicks
# New York (pinball)
# New York (typeface)
# New York Harbor
# Brooklyn Navy Yard
# Tiffany Pollard
# New York City (disambiguation)
# New York Cosmos (disambiguation)
# New York, New York (disambiguation)
# Nova Iorque
# Nowy Jork
# NY (disambiguation)
# SS New York
# SS New York City
# USS New York
# All pages with titles beginning with New York
# All pages with titles containing New York

# %%
"""import boto3
client = boto3.client(service_name="comprehendmedical",
                     region_name="us-east-1",
                     aws_access_key_id='AKIAINZKYIJQZKX6LDMQ',
                     aws_secret_access_key='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')
entities = client.detect_entities(Text="mohith is good")

#from transformers import pipeline"""

# %%
wikipedia.summary("Facebook", sentences=1

# %%
def search(self,wordd): #implemented google custom search engine api
  #responseData = 'None'
    global flag
    global page
    search_word="\"is+%s+an+organ?\"" %(wordd)
    search_word=str(search_word)
    if flag == 1:
        search_word="\"%s+is+a+disease\"" %(wordd)
        try: #searching google for the word
            url = 'https://www.googleapis.com/customsearch/v1?key=AIzaSyAUGKCa2oHSYeZynSMD6zElBKUrg596G_k&cx=00262342415310682663:xy7prswaherw&num=3&q='+search_word
            print( url)
            data = urllib2.urlopen(url)
            response_data = json.load(data)
            results=response_data['queries']['request'][0]['totalResults']
            results_count=int(results)
            print( "the results is: ",results_count)
            if(results_count == 0):
                print("no results found")
                flag = 0
                return 0
            else:
                return 1
  #except IOError:
   #print "network issues!"
        except ValueError:
            print("Problem while decoding JSON data!")

# %%
y=search("After conducting clinical reviews the patient was suffering with diabetes,htn which was revealed when a complete blood picture of the patient's blood was done. He was advised to take PRINIVIL TABS 20 MG (LISINOPRIL) 1.")

# %%
import scispacy
import spacy
import en_core_sci_sm   #The model we are going to use
from spacy import displacy

from scispacy.linking import EntityLinker
from scispacy.abbreviation import AbbreviationDetector
from scispacy.umls_linking import UmlsEntityLinker

# %%
import scispacy
import spacy
import en_core_web_sm
nlp = spacy.load("en_core_sci_sm")

# Add the abbreviation pipe to the spacy pipeline.
abbreviation_pipe = AbbreviationDetector(nlp)
nlp.add_pipe(abbreviation_pipe)

doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor neuron disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

print("Abbreviation", "\t", "Definition")
for abrv in doc._.abbreviations:
    print(f"{abrv} \t ({abrv.start}, {abrv.end}) {abrv._.long_form}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-181-2e3db8fa1dcd> in <module>
#       2 import spacy
#       3 import en_core_web_sm
# ----> 4 nlp = spacy.load("en_core_sci_sm")
#       5
#       6 # Add the abbreviation pipe to the spacy pipeline.
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      20
#      21
# ---> 22 if sys.maxunicode == 65535:
#      23     raise SystemError(Errors.E130)
#      24
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     134     path isn't present, will attempt to load a gzipped version before giving up.
#     135
# --> 136     path (unicode / Path): The data to load.
#     137     RETURNS: The loaded data.
#     138     """
#
# OSError: [E050] Can't find model 'en_core_sci_sm'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
text=""" RECORD #14806 421857826 | BHO | 95616398 | | 9654751 | 8/0/2006 12:00:00 AM | HAND CELLULITIS | Signed | DIS | Admission Date: 7/22/2006 Report Status: Signed Discharge Date: 5/24/2006
ATTENDING: DEMONT , CRAIG JEWELL MD
PRINCIPAL DIAGNOSIS: Cellulitis.
LIST OF PROBLEMS/DIAGNOSES:
1. Inflammatory breast cancer.
2. Type II diabetes.
3. Hypertension.
4. Hypercholesterolemia.
5. CHF with preserved systolic function.
6. Obstructive sleep apnea.
7. Asthma.
8. Spinal stenosis with herniated discs.
BRIEF HISTORY OF PRESENT ILLNESS: Ms. Schwarzer is a 72-year-old female with newly diagnosed ductal carcinoma and inflammatory breast cancer of the left breast with a mass in the lung that is suggestive of likely stage IV disease who has also multiple other medical problem including diabetes , who presents with a two-day history of right and left finger warmth , tenderness and swelling. The patient is undergoing chemotherapy with Adriamycin and cytoxan and is status post cycle 2 on 10/28/06 and began to feel like she was recovering from her chemotherapy approximately three days prior to admission. A spinal MRI obtained on Tuesday to evaluate her spinal stenosis was uneventful but later on that day the patient developed redness on the dorsum of her right hand in the area in which her IV was placed per the MRI. The following morning the patient had a pustular lesion on the fourth digit of her right hand distal to the dorsal redness and went to EH Urgent Care where she received one dose of ceftriaxone and was given a p.o. script for Augmentin. She was sent home but at home she developed expulsive diarrhea and vomiting on that evening , was not able to tolerate her oral antibiotics. The next day she noticed a similar lesion on the fourth digit of her left hand looking much like that on the right hand. She returned to the TMHMC urgent care for one more dose of ceftriaxone and was then admitted to the hospital for IV antibiotics. The patient denies any cat bites , travel , soil or water contract. She has no bruises , scrapes or previous lesions.
PAST MEDICAL HISTORY: As detailed above.
MEDICINES:
1. Lantus 40 units nightly.
2. Aspirin 81 mg daily.
3. Lipitor 40 mg daily.
4. Zestril 2.5 mg daily.
5. Cardizem ER 240 mg daily.
6. Lasix 20 mg daily.
7. Procrit 40000 units weekly.
8. Pamidronate.
9. Dexamethasone with chemotherapy.
10. AC chemo.
11. Neulasta.
12. Ativan p.r.n.
13. Multivitamin.
14. Iron sulfate.
15. Isosorbide dinitrate 10 mg t.i.d.
11. Allegra 60 , 000 mg b.i.d.
ALLERGIES:
1. Percodan.
2. Halothane causing fevers.
3. Atenolol causing sweating.
4. Sulfa causes a rash.
for e in doc.ents:
    print(e.text, e._.negex)
# Out:
# 14806 False
# 12:00:00 False
# 7/22/2006 False
# 5/24/2006 False
# CRAIG JEWELL MD False
# 1 False
# 2 False
# 3 False
# 4 False
# 5 False
# 6 False
# 7 False
# 8 False
# Schwarzer False
# 72-year-old False
# two-day False
# Adriamycin False
# 2 False
# 10/28/06 False
# approximately three days False
# Tuesday False
# that day False
# IV False
# MRI False
# The following morning False
# fourth False
# EH Urgent Care False
# one False
# p.o. False
# Augmentin False
# that evening False
# The next day False
# fourth False
# TMHMC False
# one False
# IV False
# 1 False
# 40 False
# 2 False
# 3 False
# 4 False
# 5 False
# Cardizem False
# daily False
# 6 False
# 7 False
# weekly False
# 8 False
# 9 False
# 10 False
# 11 False
# 12 False
# Ativan p.r.n. False
# 13 False
# Multivitamin False
# 14 False
# 15 False
# 10 False
# 11 False
# 000 mg False
# 1 False
# 2 False
# Halothane False
# 3 False
# 4 False
# Ra False
# the pofield medical center of psychiatric disturbances False
# three False
# two False
# third False
# the age of 21 False
# second False
# Du False
# Inslareca Cou Pla False
# 50 years ago False
# Ezekiel Stoviak False
# 286 False
# Three False
# the past 72 to 96 hours False
# 1/22/06 two days False
# 98.9 False
# 98 False
# 16 False
# 95% False
# JVP False
# Cardiovascular False
# S1 False
# 1 False
# 4 x 2 cm False
# third False
# 1 False
# 4.33 False
# 25.5 False
# 108 False
# first False
# 72-year-old False
# IV False
# IV False
# two days False
# 48 hours False
# Keflex False
# approximately 6 cm x 4 cm False
# MCP False
# PIP False
# Infectious False
# 48 hours False
# Keflex False
# 12 hours False
# one False
# IV False
# Keflex False
# three False
# daily False
# IV False
# the day False
# Keflex False
# Valtrex False
# ten days False
# II False
# Lantus 40 False
# Cardiovascular False
# 2005 False
# Zestril False
# Cardizem False
# Lasix False
# CPAP True
# Heme False
# one False
# 2 False
# 16 False
# Adriamycin False
# VNA False
# DISCHARGE MEDICATIONS False
# 650 False
# q.4 h. p.r.n. False
# Lipitor 40 mg daily False
# Keflex 500 mg p.o. False
# three False
# daily False
# 100 False
# weekly False
# 240 False
# daily False
# 100 False
# 300 False
# 60 False
# 2.5% False
# daily False
# 2 False
# 4 False
# q.4 h. p.r.n. False
# 40 False
# 10 False
# three False
# daily False
# Zestril 2.5 mg False
# Ativan False
# 0.5 False
# daily False
# two False
# four False
# multivitamin one
#  False
# tab False
# Valtrex False
# 1000 False
# Abed False
# 3-1182895 False
# CHINN False
# GARFIELD False
# MASUNAGA False
# BARNEY TRACY False

# %%
# create distinct colours for labels
import spacy

med7 = spacy.load("en_core_med7_lg")

# create distinct colours for labels
col_dict = {}
seven_colours = ['#e6194B', '#3cb44b', '#ffe119', '#ffd8b1', '#f58231', '#f032e6', '#42d4f4']
for label, colour in zip(med7.pipe_labels['ner'], seven_colours):
    col_dict[label] = colour

options = {'ents': med7.pipe_labels['ner'], 'colors':col_dict}

text = """RECORD #14806 421857826 | BHO | 95616398 | | 9654751 | 8/0/2006 12:00:00 AM | HAND CELLULITIS | Signed | DIS | Admission Date: 7/22/2006 Report Status: Signed Discharge Date: 5/24/2006
ATTENDING: DEMONT , CRAIG JEWELL MD
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chemotherapy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  approximately three days prior to admission. A spinal MRI obtained on Tuesday to evaluate her spinal stenosis was uneventful but later on that day the patient developed redness on the dorsum of her right hand in the area in which her IV was placed per the MRI. The following morning the patient had a pustular lesion on the fourth digit of her right hand distal to the dorsal redness and went to EH Urgent Care where she received
# <mark class="entity" style="background: #e6194B; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DOSAGE</span>
# </mark>
#  dose of
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ceftriaxone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  and was given a
# <mark class="entity" style="background: #f032e6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     p.o.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ROUTE</span>
# </mark>
#  script for
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Augmentin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# . She was sent home but at home she developed expulsive diarrhea and vomiting on that evening , was not able to tolerate her
# <mark class="entity" style="background: #f032e6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oral
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ROUTE</span>
# </mark>
#
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     antibiotics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# . The next day she noticed a similar lesion on the fourth digit of her left hand looking much like that on the right hand. She returned to the TMHMC urgent care for one more dose of
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ceftriaxone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  and was then admitted to the hospital for
# <mark class="entity" style="background: #f032e6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ROUTE</span>
# </mark>
#
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     antibiotics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# . The patient denies any cat bites , travel , soil or water contract. She has no bruises , scrapes or previous lesions.</br>PAST MEDICAL HISTORY: As detailed above.</br>MEDICINES:</br>1.
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lantus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#
# <mark class="entity" style="background: #e6194B; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40 units
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DOSAGE</span>
# </mark>
#
# <mark class="entity" style="background: #f58231; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nightly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FREQUENCY</span>
# </mark>
# .</br>2.
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aspirin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     81 mg
#     <span style="font-size: 0.8em; font-weight: bold; line-hei
# [('chemotherapy', 'DRUG'),
#  ('Adriamycin', 'DRUG'),
#  ('cytoxan', 'DRUG'),
#  ('chemotherapy', 'DRUG'),
#  ('one', 'DOSAGE'),
#  ('ceftriaxone', 'DRUG'),
#  ('p.o.', 'ROUTE'),
#  ('Augmentin', 'DRUG'),
#  ('oral', 'ROUTE'),
#  ('antibiotics', 'DRUG'),
#  ('ceftriaxone', 'DRUG'),
#  ('IV', 'ROUTE'),
#  ('antibiotics', 'DRUG'),
#  ('Lantus', 'DRUG'),
#  ('40 units', 'DOSAGE'),
#  ('nightly', 'FREQUENCY'),
#  ('Aspirin', 'DRUG'),
#  ('81 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Lipitor', 'DRUG'),
#  ('40 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Zestril', 'DRUG'),
#  ('2.5 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Cardizem ER', 'DRUG'),
#  ('240 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Lasix', 'DRUG'),
#  ('20 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Procrit', 'DRUG'),
#  ('40000 units', 'DOSAGE'),
#  ('weekly', 'FREQUENCY'),
#  ('Pamidronate', 'DRUG'),
#  ('Dexamethasone', 'DRUG'),
#  ('chemotherapy', 'DRUG'),
#  ('AC chemo', 'DRUG'),
#  ('Neulasta', 'DRUG'),
#  ('Ativan', 'DRUG'),
#  ('p.r.n.', 'FREQUENCY'),
#  ('Multivitamin', 'DRUG'),
#  ('Iron sulfate', 'DRUG'),
#  ('Isosorbide dinitrate', 'DRUG'),
#  ('10 mg', 'STRENGTH'),
#  ('t.i.d', 'FREQUENCY'),
#  ('Allegra', 'DRUG'),
#  ('60', 'STRENGTH'),
#  ('b.i.d', 'FREQUENCY'),
#  ('Percodan', 'DRUG'),
#  ('Halothane', 'DRUG'),
#  ('Atenolol', 'DRUG'),
#  ('Sulfa', 'DRUG'),
#  ('chemo', 'DRUG'),
#  ('chemo', 'DRUG'),
#  ('IV', 'ROUTE'),
#  ('vancomycin', 'DRUG'),
#  ('chemotherapy', 'DRUG'),
#  ('vancomycin', 'DRUG'),
#  ('Keflex', 'DRUG'),
#  ('IV', 'ROUTE'),
#  ('vancomycin', 'DRUG'),
#  ('vancomycin', 'DRUG'),
#  ('Keflex', 'DRUG'),
#  ('one', 'DOSAGE'),
#  ('IV', 'ROUTE'),
#  ('vancomycin', 'DRUG'),
#  ('Keflex', 'DRUG'),
#  ('topical', 'ROUTE'),
#  ('steroid', 'DRUG'),
#  ('creams', 'FORM'),
#  ('oral', 'ROUTE'),
#  ('cephalosporin', 'DRUG'),
#  ('IV', 'ROUTE'),
#  ('acyclovir', 'DRUG'),
#  ('Valtrex', 'DRUG'),
#  ('t.i.d', 'FREQUENCY'),
#  ('Keflex', 'DRUG'),
#  ('Valtrex', 'DRUG'),
#  ('ten days', 'DURATION'),
#  ('insulin', 'DRUG'),
#  ('Lantus', 'DRUG'),
#  ('40 units', 'DOSAGE'),
#  ('nightly', 'FREQUENCY'),
#  ('aspirin', 'DRUG'),
#  ('statin', 'DRUG'),
#  ('Zestril', 'DRUG'),
#  ('Cardizem', 'DRUG'),
#  ('Lasix', 'DRUG'),
#  ('nitrates', 'DRUG'),
#  ('one unit', 'DOSAGE'),
#  ('packed red blood cells', 'DRUG'),
#  ('neoadjuvant chemotherapy', 'DRUG'),
#  ('Adriamycin', 'DRUG'),
#  ('cytoxan', 'DRUG'),
#  ('chemotherapy', 'DRUG'),
#  ('Tylenol', 'DRUG'),
#  ('650 mg', 'STRENGTH'),
#  ('p.o.', 'ROUTE'),
#  ('q.4 h. p.r.n.', 'FREQUENCY'),
#  ('aspirin', 'DRUG'),
#  ('81 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Lipitor', 'DRUG'),
#  ('40 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('bacitracin', 'DRUG'),
#  ('topical', 'ROUTE'),
#  ('twice daily', 'FREQUENCY'),
#  ('Keflex', 'DRUG'),
#  ('500 mg', 'STRENGTH'),
#  ('p.o.', 'ROUTE'),
#  ('q.i.d. x5 days', 'FREQUENCY'),
#  ('5/24/06', 'STRENGTH'),
#  ('chlorhexidine', 'DRUG'),
#  ('three', 'DOSAGE'),
#  ('packets', 'FORM'),
#  ('daily', 'FREQUENCY'),
#  ('darbepoetin', 'DRUG'),
#  ('100 mcg', 'STRENGTH'),
#  ('subcutaneously', 'ROUTE'),
#  ('weekly', 'FREQUENCY'),
#  ('diltiazem ER', 'DRUG'),
#  ('240 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Colace', 'DRUG'),
#  ('100 mg', 'STRENGTH'),
#  ('twice daily', 'FREQUENCY'),
#  ('ferrous sulfate', 'DRUG'),
#  ('300 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Allegra', 'DRUG'),
#  ('60 mg', 'STRENGTH'),
#  ('twice\ndaily', 'FREQUENCY'),
#  ('Lasix', 'DRUG'),
#  ('20 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('hydrocortisone', 'DRUG'),
#  ('2.5%', 'STRENGTH'),
#  ('cream', 'FORM'),
#  ('topically', 'ROUTE'),
#  ('twice daily', 'FREQUENCY'),
#  ('Dilaudid', 'DRUG'),
#  ('2 to 4 mg', 'STRENGTH'),
#  ('p.o.', 'ROUTE'),
#  ('q.4 h. p.r.n.', 'FREQUENCY'),
#  ('Lantus', 'DRUG'),
#  ('40 units', 'DOSAGE'),
#  ('subcutaneously', 'ROUTE'),
#  ('every evening', 'FREQUENCY'),
#  ('isosorbide\ndinitrate', 'DRUG'),
#  ('10 mg', 'STRENGTH'),
#  ('three times daily', 'FREQUENCY'),
#  ('Zestril', 'DRUG'),
#  ('2.5 mg', 'STRENGTH'),
#  ('daily', 'FREQUENCY'),
#  ('Ativan', 'DRUG'),
#  ('0.5 mg', 'STRENGTH'),
#  ('twice daily p.r.n', 'FREQUENCY'),
#  ('spray', 'FORM'),
#  ('two', 'DOSAGE'),
#  ('sprays', 'FORM'),
#  ('nasally', 'ROUTE'),
#  ('four times a day', 'FREQUENCY'),
#  ('multivitamin', 'DRUG'),
#  ('one', 'DOSAGE'),
#  ('tab', 'FORM'),
#  ('daily', 'FREQUENCY'),
#  ('Valtrex', 'DRUG'),
#  ('1000 mg', 'STRENGTH'),
#  ('q.8 h. x21 doses', 'FREQUENCY'),
#  ('triamcinolone', 'DRUG'),
#  ('cream', 'FORM'),
#  ('topically', 'ROUTE'),
#  ('once daily', 'FREQUENCY')]

# %%
drugs=[]
for ent in doc.ents:
    if ent.label_ == 'DRUG':
        drugs.append(ent.text)
drugs
# Out:
# ['chemotherapy',
#  'Adriamycin',
#  'cytoxan',
#  'chemotherapy',
#  'ceftriaxone',
#  'Augmentin',
#  'antibiotics',
#  'ceftriaxone',
#  'antibiotics',
#  'Lantus',
#  'Aspirin',
#  'Lipitor',
#  'Zestril',
#  'Cardizem ER',
#  'Lasix',
#  'Procrit',
#  'Pamidronate',
#  'Dexamethasone',
#  'chemotherapy',
#  'AC chemo',
#  'Neulasta',
#  'Ativan',
#  'Multivitamin',
#  'Iron sulfate',
#  'Isosorbide dinitrate',
#  'Allegra',
#  'Percodan',
#  'Halothane',
#  'Atenolol',
#  'Sulfa',
#  'chemo',
#  'chemo',
#  'vancomycin',
#  'chemotherapy',
#  'vancomycin',
#  'Keflex',
#  'vancomycin',
#  'vancomycin',
#  'Keflex',
#  'vancomycin',
#  'Keflex',
#  'steroid',
#  'cephalosporin',
#  'acyclovir',
#  'Valtrex',
#  'Keflex',
#  'Valtrex',
#  'insulin',
#  'Lantus',
#  'aspirin',
#  'statin',
#  'Zestril',
#  'Cardizem',
#  'Lasix',
#  'nitrates',
#  'packed red blood cells',
#  'neoadjuvant chemotherapy',
#  'Adriamycin',
#  'cytoxan',
#  'chemotherapy',
#  'Tylenol',
#  'aspirin',
#  'Lipitor',
#  'bacitracin',
#  'Keflex',
#  'chlorhexidine',
#  'darbepoetin',
#  'diltiazem ER',
#  'Colace',
#  'ferrous sulfate',
#  'Allegra',
#  'Lasix',
#  'hydrocortisone',
#  'Dilaudid',
#  'Lantus',
#  'isosorbide\ndinitrate',
#  'Zestril',
#  'Ativan',
#  'multivitamin',
#  'Valtrex',
#  'triamcinolone']
